# %% [markdown]
# #### Env: Minh

# %%
import pandas as pd
from upgrade import *
from causallearn.utils.cit import CIT
import numpy as np
from pathlib import Path
import os
from tqdm import tqdm

dataname = "erdos_renyi/d40_p0.1"
mi = 5      # The number of values a variable can take is ranged in [2, mi-1]
di = 1.0      # The dirichlet alpha that controls the data distribution
n = 10      # The number of data silos

TMB_activated = True

silos = []

folderpath = f"./data/distributed/{dataname}/m{mi}_d{di}_n{n}"
groundtruth = np.loadtxt(f"./data/distributed/{dataname}/adj.txt")

if not Path(folderpath).exists():
    print("Folder", folderpath, "not exist!")
else:
    for file in sorted(os.listdir(folderpath)):
        filename = os.path.join(folderpath, file)
        silo_data = pd.read_csv(filename)
        silos.append(silo_data)
        print("Loaded file:", filename, end="\t")
        print(len(silo_data), " Instances", len(silo_data.columns), "Variables")

merged_df = pd.concat(silos, axis=0)
merged_df = merged_df.reindex(sorted(merged_df.columns, key=lambda item: int(item[1:])), axis=1)
all_vars = list(merged_df.columns)
# Out:
# Loaded file: ./data/distributed/erdos_renyi/d40_p0.1/m5_d1.0_n10/silo-0.csv	2500  Instances 40 Variables
# Loaded file: ./data/distributed/erdos_renyi/d40_p0.1/m5_d1.0_n10/silo-1.csv	2500  Instances 40 Variables
# Loaded file: ./data/distributed/erdos_renyi/d40_p0.1/m5_d1.0_n10/silo-2.csv	2500  Instances 40 Variables
# Loaded file: ./data/distributed/erdos_renyi/d40_p0.1/m5_d1.0_n10/silo-3.csv	2500  Instances 40 Variables
# Loaded file: ./data/distributed/erdos_renyi/d40_p0.1/m5_d1.0_n10/silo-4.csv	2500  Instances 40 Variables
# Loaded file: ./data/distributed/erdos_renyi/d40_p0.1/m5_d1.0_n10/silo-5.csv	2500  Instances 40 Variables
# Loaded file: ./data/distributed/erdos_renyi/d40_p0.1/m5_d1.0_n10/silo-6.csv	2500  Instances 40 Variables
# Loaded file: ./data/distributed/erdos_renyi/d40_p0.1/m5_d1.0_n10/silo-7.csv	2500  Instances 40 Variables
# Loaded file: ./data/distributed/erdos_renyi/d40_p0.1/m5_d1.0_n10/silo-8.csv	2500  Instances 40 Variables
# Loaded file: ./data/distributed/erdos_renyi/d40_p0.1/m5_d1.0_n10/silo-9.csv	2500  Instances 40 Variables

# %%
confidence = 0.01
connectivity = {var: [] for var in all_vars}
chisq_obj = CIT(merged_df, "chisq")

for X in connectivity.keys():
    other_vars = list(set(all_vars) - set(connectivity[X]) - set([X]))
    for Y in other_vars:
        pval = chisq_obj(all_vars.index(X), all_vars.index(Y), []) # type: ignore
        if pval <= confidence: # type: ignore
            connectivity[X] = list(set(connectivity[X]) | set([Y]))
            connectivity[Y] = list(set(connectivity[Y]) | set([X]))

# %%
basis = []
ordering = sorted(list(connectivity.keys()), key=lambda item: len(connectivity[item]), reverse=False)
while len(ordering):
    var = ordering.pop(0)
    ordering = list(set(ordering) - set(connectivity[var]))
    basis.append(var)

print(basis)
# Out:
# ['X39', 'X38', 'X36', 'X3', 'X27', 'X20', 'X7', 'X14']

# %%
def generate_uniform_distributions(P0: np.ndarray, num_gen=100, gamma2=0.8):
    Ulist = list(np.eye(P0.shape[0]))
    # Compute the boundary points
    boundaries = []
    for i in range(len(Ulist)):
        if P0[i]/gamma2 < 1:
            alpha_i = 1/(1 - P0[i]) * (1 - P0[i]/(gamma2 + 0.001))
            boundary_i = alpha_i * P0 + (1 - alpha_i) * Ulist[i]
        else:
            boundary_i = Ulist[i]
        boundaries.append(boundary_i)
    
    boundaries = np.stack(boundaries)
    w = np.random.uniform(0, 1, (num_gen * 30, len(Ulist)))
    w = w/w.sum(axis=1, keepdims=True)
    
    kmeans = KMeans(n_clusters=num_gen, n_init="auto")
    kmeans.fit(w @ boundaries)
    res = kmeans.cluster_centers_
    
    return res

# %%
def generate_uniform_distributions(P0: np.ndarray, num_gen=100, gamma2=0.8):
    Ulist = list(np.eye(P0.shape[0]))
    # Compute the boundary points
    boundaries = []
    for i in range(len(Ulist)):
        if P0[i]/gamma2 < 1:
            alpha_i = 1/(1 - P0[i]) * (1 - P0[i]/(gamma2 + 0.001))
            boundary_i = alpha_i * P0 + (1 - alpha_i) * Ulist[i]
        else:
            boundary_i = Ulist[i]
        boundaries.append(boundary_i)
    
    boundaries = np.stack(boundaries)
    w = np.random.uniform(0, 1, (num_gen * 30, len(Ulist)))
    w = w/w.sum(axis=1, keepdims=True)
    
    kmeans = KMeans(n_clusters=num_gen, n_init="auto")
    kmeans.fit(w @ boundaries)
    res = kmeans.cluster_centers_
    return res


def multivariate_sampling(data: pd.DataFrame, variables: list, sample_dis: dict, instance_index):
    remains = deepcopy(variables)
    while len(remains):
        sampling_var = remains.pop(0)
        distribution = sample_dis[sampling_var][instance_index]
        _, all_index = univariate_sampling(data, sampling_var, {i: distribution[i] for i in range(distribution.shape[0])})
    return all_index

# %%
num_env = 50
gamma2 = 0.4

sample_dis = {var: generate_uniform_distributions(P0=marginal_prob(merged_df, [var]),
                                                num_gen=num_env, 
                                                gamma2=np.power(gamma2, 1./len(basis))) for var in basis}

silos_index = [multivariate_sampling(merged_df, basis, sample_dis, i) for i in range(num_env)]

# %%
from copy import deepcopy
from causallearn.utils.cit import CIT


def GSMB(indexes, confidence=0.01):
    data = merged_df.iloc[indexes].reset_index().drop(columns=['index'])
    chisq_obj = CIT(data, "chisq") # construct a CIT instance with data and method name
    all_var_idx = [i for i in range(len(data.columns))]
    markov_blankets_idx = {i: [] for i in range(len(data.columns))}

    for X in all_var_idx:
        # S = markov_blankets_idx[X]
        S = []
        # X = 6
        prev_length = 0
        count = 0
        while True:
            count += 1
            # print("==============New cycle==================")
            for Y in list(set(all_var_idx) - set(S) - set([X])):
                if Y != X:
                    pval = chisq_obj(X, Y, S) # type:ignore
                    if pval <= confidence: # type:ignore
                        S.append(Y)
            
            for Y in deepcopy(S):
                pval = chisq_obj(X, Y, list(set(S) - set([Y]))) # type:ignore
                if pval > confidence: # type:ignore
                    S.remove(Y)
            
            if (len(S) - prev_length == 0) or (count > 2):
                break
            else:
                prev_length = len(S)
        
        # markov_blankets[data.columns[X]] = [data.columns[i] for i in S]
        markov_blankets_idx[X] = list(set(markov_blankets_idx[X])|set(S))
        # for i in S:
        #     if X not in markov_blankets_idx[i]:
        #         markov_blankets_idx[i].append(X)
    
    markov_blankets = {var: [] for var in all_vars}
    for idx, mb_idxes in markov_blankets_idx.items():
        var = all_vars[idx]
        markov_blankets[var] = [all_vars[i] for i in mb_idxes]
    
    return markov_blankets

# %%
def true_markov_blanket(adj_matrix, var_idx):
    parents = np.where(adj_matrix[:, var_idx])[0]
    children = np.where(adj_matrix[var_idx])[0]
    
    spouses = set()
    for c in children:
        for sp in np.where(adj_matrix[:, c])[0]:
            spouses.add(sp)
    
    spouses = list(spouses)
    return parents, children, spouses


def to_list(all_vars, mb_idx_list):
    return [all_vars[i] for i in mb_idx_list]

# %%
markov_blankets = {var: [] for var in all_vars}

if TMB_activated:
    for var in markov_blankets.keys():
        pa, ch, sp = true_markov_blanket(groundtruth, int(var[1:]) - 1)
        markov_blankets[var] = list(set(to_list(all_vars, list(set(pa)|set(ch)|set(sp)))) - set([var]))
else:
    markov_blankets = GSMB([i for i in range(len(merged_df))])

# %%
# Check the quality of the markov blanket

# for var in true_markov_blankets.keys():
#     pa, ch, sp = true_markov_blanket(groundtruth, int(var[1:]) - 1)
#     true_val = len(list(set(pa)|set(ch)|set(sp) - set([var])))
#     print(var, "Index", int(var[1:]) - 1, "\t", len(true_markov_blankets[var]), "/", true_val)

# %%
def recursive_conn(neighbors):
  output = []
  if len(neighbors) <= 1:
    output = [neighbors]
  else:
    for i in neighbors:
      res_i = [i] + recursive_conn(list(set(neighbors)&set(markov_blankets[i])))
      output.append(res_i)
  return output

def unfold(input):
  """
  Arguments:
    input: [var, var, ..., [var, ...], [var, ...]]

  that has a number of non-list element and a number of list element
  """
  cut_index = 0
  while cut_index < len(input):
    cut_index += 1
    if isinstance(input[cut_index], list):
      break

  out = []
  for i in range(cut_index, len(input)):
    out.append([*input[:cut_index], *input[i]])
  return out

# %%
recursive_outputs = {}

for anchor_var in tqdm(markov_blankets.keys()):
    recursive_outputs[anchor_var] = recursive_conn(deepcopy(markov_blankets[anchor_var]))
# Out:
# 100%|██████████| 40/40 [00:20<00:00,  1.92it/s]

# %%
potential_parents = {}

for anchor_var in tqdm(markov_blankets.keys(), leave=False):
    recursive_output = recursive_outputs[anchor_var]

    final_output = set()
    for i in range(len(recursive_output)):
        test_case = deepcopy(recursive_output[i])
        unique_elements = set()
        first_element = test_case.pop(0)
        while len(test_case):
            examine_group = test_case.pop(0)
            if len(examine_group) and not isinstance(examine_group[0], list) and isinstance(examine_group[-1], list):
                unfolded = unfold(examine_group)
                test_case += [*unfold(examine_group)]
            else:
                unique_elements.add(tuple(sorted(examine_group + [first_element])))
        final_output = final_output|unique_elements
    potential_parents[anchor_var] = [j for j in final_output]

# %%
from itertools import combinations


true_causal_parents = {var: [] for var in all_vars}
invariance_hardcap = 1e-3

# for var in tqdm(true_causal_parents.keys(), leave=False):
var = 'X2'
best_variance = invariance_hardcap
best_comb = []
buffers = {}

for test_case in potential_parents[var]:
    print(test_case)
    for l in range(1, len(test_case) + 1):
        results = []
        inputs = [[silos_index, var, comb] for comb in list(combinations(test_case, l))]
        for comb in list(combinations(test_case, l)):
            key = tuple(sorted(comb))
            if key in buffers.keys():
                variance = buffers[key]
                print(f"\tRecognized Comb[{key}] = {variance}")
            else:
                variance, _ = compute_weighted_variance_viaindexesv2(silos_index, var, list(key))
                buffers[key] = variance
                print(f"\tRemembering Comb[{key}] = {variance}")
                
            results.append([variance, key])
            
        lowest_variance, cor_comb = sorted(results, key=lambda item: item[0])[0]
        if lowest_variance < best_variance:
            best_variance = lowest_variance
            best_comb = cor_comb

true_causal_parents[var] = (best_comb, best_variance) # type:ignore
# Out:
# ('X18', 'X20', 'X31', 'X33', 'X38')
# 	Remembering Comb[('X18',)] = 1.091839148799073e-07
# 	Remembering Comb[('X20',)] = 1.0620547744865459e-07
# 	Remembering Comb[('X31',)] = 9.784821407576818e-08
# 	Remembering Comb[('X33',)] = 1.1187703633024086e-07
# 	Remembering Comb[('X38',)] = 9.990015214166418e-08
# 	Remembering Comb[('X18', 'X20')] = 1.0367023347042551e-07
# 	Remembering Comb[('X18', 'X31')] = 1.097388836979963e-07
# 	Remembering Comb[('X18', 'X33')] = 1.104747005769992e-07
# 	Remembering Comb[('X18', 'X38')] = 1.0973159114650887e-07
# 	Remembering Comb[('X20', 'X31')] = 1.0121914132146794e-07
# 	Remembering Comb[('X20', 'X33')] = 1.0332767931727366e-07
# 	Remembering Comb[('X20', 'X38')] = 1.0223122850738607e-07
# 	Remembering Comb[('X31', 'X33')] = 1.1033920997064235e-07
# 	Remembering Comb[('X31', 'X38')] = 1.0407126965585849e-07
# 	Remembering Comb[('X33', 'X38')] = 1.040205473009808e-07
# 	Remembering Comb[('X18', 'X20', 'X31')] = 1.0868428243220747e-07
# 	Remembering Comb[('X18', 'X20', 'X33')] = 1.084428546882025e-07
# 	Remembering Comb[('X18', 'X20', 'X38')] = 1.0531615077338009e-07
# 	Remembering Comb[('X18', 'X31', 'X33')] = 1.1307467281797576e-07
# 	Remembering Comb[('X18', 'X31', 'X38')] = 1.1043400197851377e-07
# 	Remembering Comb[('X18', 'X33', 'X38')] = 1.1228236232673437e-07
# 	Remembering Comb[('X20', 'X31', 'X33')] = 1.0659620409574471e-07
# 	Remembering Comb[('X20', 'X31', 'X38')] = 1.0387377328182131e-07
# 	Remembering Comb[('X20', 'X33', 'X38')] = 1.0431747993523363e-07
# 	Remembering Comb[('X31', 'X33', 'X38')] = 1.0644138908459194e-07
# 	Remembering Comb[('X18', 'X20', 'X31', 'X33')] = 1.1757375018910546e-07
# 	Remembering Comb[('X18', 'X20', 'X31', 'X38')] = 1.0761072519325023e-07
# 	Remembering Comb[('X18', 'X20', 'X33', 'X38')] = 1.1289590567384624e-07
# 	Remembering Comb[('X18', 'X31', 'X33', 'X38')] = 1.1435737415817634e-07
# 	Remembering Comb[('X20', 'X31', 'X33', 'X38')] = 1.0849270383569929e-07
# 	Remembering Comb[('X18', 'X20', 'X31', 'X33', 'X38')] = 1.2730436105151826e-07
# ('X29', 'X30', 'X34', 'X38')
# 	Remembering Comb[('X29',)] = 1.0267292674783365e-07
# 	Remembering Comb[('X30',)] = 9.623927447860778e-08
# 	Remembering Comb[('X34',)] = 1.0384399076136886e-07
# 	Recognized Comb[('X38',)] = 9.990015214166418e-08
# 	Remembering Comb[('X29', 'X30')] = 1.0593381117444441e-07
# 	Remembering Comb[('X29', 'X34')] = 1.0394818866341507e-07
# 	Remembering Comb[('X29', 'X38')] = 1.0157684229443321e-07
# 	Remembering Comb[('X30', 'X34')] = 1.0161824186106294e-07
# 	Remembering Comb[('X30', 'X38')] = 1.0424744562999352e-07
# 	Remembering Comb[('X34', 'X38')] = 1.0583806831614636e-07
# 	Remembering Comb[('X29', 'X30', 'X34')] = 1.0467834768330562e-07
# 	Remembering Comb[('X29', 'X30', 'X38')] = 1.0263527505778177e-07
# 	Remembering Comb[('X29', 'X34', 'X38')] = 1.0316783549188795e-07
# 	Remembering Comb[('X30', 'X34', 'X38')] = 1.0832374098944765e-07
# 	Remembering Comb[('X29', 'X30', 'X34', 'X38')] = 1.0451409045974545e-07
# ('X20', 'X28', 'X31', 'X34', 'X37')
# 	Recognized Comb[('X20',)] = 1.0620547744865459e-07
# 	Remembering Comb[('X28',)] = 1.06090636102235e-07
# 	Recognized Comb[('X31',)] = 9.784821407576818e-08
# 	Recognized Comb[('X34',)] = 1.0384399076136886e-07
# 	Remembering Comb[('X37',)] = 1.0043017351253842e-07
# 	Remembering Comb[('X20', 'X28')] = 1.0817289751521434e-07
# 	Recognized Comb[('X20', 'X31')] = 1.0121914132146794e-07
# 	Remembering Comb[('X20', 'X34')] = 1.1082081034859826e-07
# 	Remembering Comb[('X20', 'X37')] = 1.0514790384355041e-07
# 	Remembering Comb[('X28', 'X31')] = 1.0007469595512762e-07
# 	Remembering Comb[('X28', 'X34')] = 1.0552620155065991e-07
# 	Remembering Comb[('X28', 'X37')] = 1.088973952212691e-07
# 	Remembering Comb[('X31', 'X34')] = 9.596014638977938e-08
# 	Remembering Comb[('X31', 'X37')] = 9.854438824535334e-08
# 	Remembering Comb[('X34', 'X37')] = 9.995249057723862e-08
# 	Remembering Comb[('X20', 'X28', 'X31')] = 1.0295944896461987e-07
# 	Remembering Comb[('X20', 'X28', 'X34')] = 1.0612434040563769e-07
# 	Remembering Comb[('X20', 'X28', 'X37')] = 1.0604453822504629e-07
# 	Remembering Comb[('X20', 'X31', 'X34')] = 1.0711275873477329e-07
# 	Remembering Comb[('X20', 'X31', 'X37')] = 1.0053599266206954e-07
# 	Remembering Comb[('X20', 'X34', 'X37')] = 1.0301125817569319e-07
# 	Remembering Comb[('X28', 'X31', 'X34')] = 9.99238689116765e-08
# 	Remembering Comb[('X28', 'X31', 'X37')] = 1.0060463239350425e-07
# 	Remembering Comb[('X28', 'X34', 'X37')] = 1.0469604297293467e-07
# 	Remembering Comb[('X31', 'X34', 'X37')] = 1.013178435287446e-07
# 	Remembering Comb[('X20', 'X28', 'X31', 'X34')] = 1.0492733715077318e-07
# 	Remembering Comb[('X20', 'X28', 'X31', 'X37')] = 1.0249712350817512e-07
# 	Remembering Comb[('X20', 'X28', 'X34', 'X37')] = 1.0455375643185116e-07
# 	Remembering Comb[('X20', 'X31', 'X34', 'X37')] = 1.0354823909909216e-07
# 	Remembering Comb[('X28', 'X31', 'X34', 'X37')] = 1.0254891244978198e-07
# 	Remembering Comb[('X20', 'X28', 'X31', 'X34', 'X37')] = 1.0530798367660827e-07
# ('X16', 'X18', 'X31', 'X33')
# 	Remembering Comb[('X16',)] = 9.77956276711301e-08
# 	Recognized Comb[('X18',)] = 1.091839148799073e-07
# 	Recognized Comb[('X31',)] = 9.784821407576818e-08
# 	Recognized Comb[('X33',)] = 1.1187703633024086e-07
# 	Remembering Comb[('X16', 'X18')] = 1.0675295454985596e-07
# 	Remembering Comb[('X16', 'X31')] = 1.0768220350862676e-07
# 	Remembering Comb[('X16', 'X33')] = 1.0401184662293233e-07
# 	Recognized Comb[('X18', 'X31')] = 1.097388836979963e-07
# 	Recognized Comb[('X18', 'X33')] = 1.104747005769992e-07
# 	Recognized Comb[('X31', 'X33')] = 1.1033920997064235e-07
# 	Remembering Comb[('X16', 'X18', 'X31')] = 1.1381475327612792e-07
# 	Remembering Comb[('X16', 'X18', 'X33')] = 1.1359844858052206e-07
# 	Remembering Comb[('X16', 'X31', 'X33')] = 1.0719027541016405e-07
# 	Recognized Comb[('X18', 'X31', 'X33')] = 1.1307467281797576e-07
# 	Remembering Comb[('X16', 'X18', 'X31', 'X33')] = 1.1718798126604157e-07
# ('X28', 'X29', 'X3', 'X34')
# 	Recognized Comb[('X28',)] = 1.06090636102235e-07
# 	Recognized Comb[('X29',)] = 1.0267292674783365e-07
# 	Remembering Comb[('X3',)] = 9.028188141014899e-08
# 	Recognized Comb[('X34',)] = 1.0384399076136886e-07
# 	Remembering Comb[('X28', 'X29')] = 1.0196420877692764e-07
# 	Remembering Comb[('X28', 'X3')] = 1.0523029396787995e-07
# 	Recognized Comb[('X28', 'X34')] = 1.0552620155065991e-07
# 	Remembering Comb[('X29', 'X3')] = 9.904852523209473e-08
# 	Recognized Comb[('X29', 'X34')] = 1.0394818866341507e-07
# 	Remembering Comb[('X3', 'X34')] = 1.0184542244529584e-07
# 	Remembering Comb[('X28', 'X29', 'X3')] = 1.0646684444540116e-07
# 	Remembering Comb[('X28', 'X29', 'X34')] = 1.0438592834234623e-07
# 	Remembering Comb[('X28', 'X3', 'X34')] = 1.0854297423236192e-07
# 	Remembering Comb[('X29', 'X3', 'X34')] = 1.088471442844375e-07
# 	Remembering Comb[('X28', 'X29', 'X3', 'X34')] = 1.1345833661006231e-07
# ('X18', 'X29', 'X33', 'X38')
# 	Recognized Comb[('X18',)] = 1.091839148799073e-07
# 	Recognized Comb[('X29',)] = 1.0267292674783365e-07
# 	Recognized Comb[('X33',)] = 1.1187703633024086e-07
# 	Recognized Comb[('X38',)] = 9.990015214166418e-08
# 	Remembering Comb[('X18', 'X29')] = 1.0200226649299218e-07
# 	Recognized Comb[('X18', 'X33')] = 1.104747005769992e-07
# 	Recognized Comb[('X18', 'X38')] = 1.0973159114650887e-07
# 	Remembering Comb[('X29', 'X33')] = 1.0247034050219986e-07
# 	Recognized Comb[('X29', 'X38')] = 1.0157684229443321e-07
# 	Recognized Comb[('X33', 'X38')] = 1.040205473009808e-07
# 	Remembering Comb[('X18', 'X29', 'X33')] = 1.047202624692174e-07
# 	Remembering Comb[('X18', 'X29', 'X38')] = 1.0439895151415114e-07
# 	Recognized Comb[('X18', 'X33', 'X38')] = 1.1228236232673437e-07
# 	Remembering Comb[('X29', 'X33', 'X38')] = 1.025917517962551e-07
# 	Remembering Comb[('X18', 'X29', 'X33', 'X38')] = 1.0899825522598416e-07
# ('X15', 'X20', 'X30', 'X31', 'X32', 'X34', 'X37', 'X38', 'X5')
# 	Remembering Comb[('X15',)] = 8.720948197569742e-08
# 	Recognized Comb[('X20',)] = 1.0620547744865459e-07
# 	Recognized Comb[('X30',)] = 9.623927447860778e-08
# 	Recognized Comb[('X31',)] = 9.784821407576818e-08
# 	Remembering Comb[('X32',)] = 1.0952058602166966e-07
# 	Recognized Comb[('X34',)] = 1.0384399076136886e-07
# 	Recognized Comb[('X37',)] = 1.0043017351253842e-07
# 	Recognized Comb[('X38',)] = 9.990015214166418e-08
# 	Remembering Comb[('X5',)] = 9.955714832066585e-08
# 	Remembering Comb[('X15', 'X20')] = 9.401178780031829e-08
# 	Remembering Comb[('X15', 'X30')] = 1.0073045917783827e-07
# 	Remembering Comb[('X15', 'X31')] = 1.00167312338887e-07
# 	Remembering Comb[('X15', 'X32')] = 9.540570718048513e-08
# 	Remembering Comb[('X15', 'X34')] = 9.955549996398415e-08
# 	Remembering Comb[('X15', 'X37')] = 9.533474462643245e-08
# 	Remembering Comb[('X15', 'X38')] = 9.685041565605953e-08
# 	Remembering Comb[('X15', 'X5')] = 1.009779542060838e-07
# 	Remembering Comb[('X20', 'X30')] = 1.0004379367649865e-07
# 	Recognized Comb[('X20', 'X31')] = 1.0121914132146794e-07
# 	Remembering Comb[('X20', 'X32')] = 1.0053418195599895e-07
# 	Recognized Comb[('X20', 'X34')] = 1.1082081034859826e-07
# 	Recognized Comb[('X20', 'X37')] = 1.0514790384355041e-07
# 	Recognized Comb[('X20', 'X38')] = 1.0223122850738607e-07
# 	Remembering Comb[('X20', 'X5')] = 1.0566600295426554e-07
# 	Remembering Comb[('X30', 'X31')] = 9.76054833401526e-08
# 	Remembering Comb[('X30', 'X32')] = 1.0342415570079469e-07
# 	Recognized Comb[('X30', 'X34')] = 1.0161824186106294e-07
# 	Remembering Comb[('X30', 'X37')] = 9.593672684847123e-08
# 	Recognized Comb[('X30', 'X38')] = 1.0424744562999352e-07
# 	Remembering Comb[('X30', 'X5')] = 1.0288943675079804e-07
# 	Remembering Comb[('X31', 'X32')] = 1.0498811156491484e-07
# 	Recognized Comb[('X31', 'X34')] = 9.596014638977938e-08
# 	Recognized Comb[('X31', 'X37')] = 9.854438824535334e-08
# 	Recognized Comb[('X31', 'X38')] = 1.0407126965585849e-07
# 	Remembering Comb[('X31', 'X5')] = 1.0737030824934628e-07
# 	Remembering Comb[('X32', 'X34')] = 1.0494179565284246e-07
# 	Remembering Comb[('X32', 'X37')] = 9.991089565159122e-08
# 	Remembering Comb[('X32', 'X38')] = 1.128209059884482e-07
# 	Remembering Comb[('X32', 'X5')] = 1.0620470671085809e-07
# 	Recognized Comb[('X34', 'X37')] = 9.995249057723862e-08
# 	Recognized Comb[('X34', 'X38')] = 1.0583806831614636e-07
# 	Remembering Comb[('X34', 'X5')] = 1.0914455134767918e-07
# 	Remembering Comb[('X37', 'X38')] = 1.0137323758317765e-07
# 	Remembering Comb[('X37', 'X5')] = 1.0262996380353734e-07
# 	Remembering Comb[('X38', 'X5')] = 1.0598644066264256e-07
# 	Remembering Comb[('X15', 'X20', 'X30')] = 1.0116750879789541e-07
# 	Remembering Comb[('X15', 'X20', 'X31')] = 1.0020092288616913e-07
# 	Remembering Comb[('X15', 'X20', 'X32')] = 9.64053588792288e-08
# 	Remembering Comb[('X15', 'X20', 'X34')] = 1.0393699695760559e-07
# 	Remembering Comb[('X15', 'X20', 'X37')] = 1.0015209164349859e-07
# 	Remembering Comb[('X15', 'X20', 'X38')] = 9.82277035320667e-08
# 	Remembering Comb[('X15', 'X20', 'X5')] = 1.0041500182980878e-07
# 	Remembering Comb[('X15', 'X30', 'X31')] = 1.0460307199628397e-07
# 	Remembering Comb[('X15', 'X30', 'X32')] = 9.986602937668746e-08
# 	Remembering Comb[('X15', 'X30', 'X34')] = 1.0246716314259389e-07
# 	Remembering Comb[('X15', 'X30', 'X37')] = 1.0205178854800574e-07
# 	Remembering Comb[('X15', 'X30', 'X38')] = 1.0344429278048494e-07
# 	Remembering Comb[('X15', 'X30', 'X5')] = 1.0305064698304455e-07
# 	Remembering Comb[('X15', 'X31', 'X32')] = 1.010909004190298e-07
# 	Remembering Comb[('X15', 'X31', 'X34')] = 1.0339586329574346e-07
# 	Remembering Comb[('X15', 'X31', 'X37')] = 9.963184128953408e-08
# 	Remembering Comb[('X15', 'X31', 'X38')] = 1.0325546433737277e-07
# 	Remembering Comb[('X15', 'X31', 'X5')] = 1.0610093589474134e-07
# 	Remembering Comb[('X15', 'X32', 'X34')] = 1.0078738396979588e-07
# 	Remembering Comb[('X15', 'X32', 'X37')] = 1.015919468011532e-07
# 	Remembering Comb[('X15', 'X32', 'X38')] = 1.0327875002468286e-07
# 	Remembering Comb[('X15', 'X32', 'X5')] = 9.965125220895426e-08
# 	Remembering Comb[('X15', 'X34', 'X37')] = 1.0139139245614437e-07
# 	Remembering Comb[('X15', 'X34', 'X38')] = 1.0219407324330174e-07
# 	Remembering Comb[('X15', 'X34', 'X5')] = 1.029703077180509e-07
# 	Remembering Comb[('X15', 'X37', 'X38')] = 1.0279341033073346e-07
# 	Remembering Comb[('X15', 'X37', 'X5')] = 1.0241178799666611e-07
# 	Remembering Comb[('X15', 'X38', 'X5')] = 1.0315441890726794e-07
# 	Remembering Comb[('X20', 'X30', 'X31')] = 1.008544800066384e-07
# 	Remembering Comb[('X20', 'X30', 'X32')] = 1.0202575778908645e-07
# 	Remembering Comb[('X20', 'X30', 'X34')] = 1.0432876034595566e-07
# 	Remembering Comb[('X20', 'X30', 'X37')] = 1.0277677985422529e-07
# 	Remembering Comb[('X20', 'X30', 'X38')] = 1.0511914439560888e-07
# 	Remembering Comb[('X20', 'X30', 'X5')] = 1.0452695409437257e-07
# 	Remembering Comb[('X20', 'X31', 'X32')] = 1.0102502685929904e-07
# 	Recognized Comb[('X20', 'X31', 'X34')] = 1.0711275873477329e-07
# 	Recognized Comb[('X20', 'X31', 'X37')] = 1.0053599266206954e-07
# 	Recognized Comb[('X20', 'X31', 'X38')] = 1.0387377328182131e-07
# 	Remembering Comb[('X20', 'X31', 'X5')] = 1.0485453205662281e-07
# 	Remembering Comb[('X20', 'X32', 'X34')] = 1.0286430969905233e-07
# 	Remembering Comb[('X20', 'X32', 'X37')] = 1.0080986124740828e-07
# 	Remembering Comb[('X20', 'X32', 'X38')] = 1.0727856421974118e-07
# 	Remembering Comb[('X20', 'X32', 'X5')] = 1.0371348088167324e-07
# 	Recognized Comb[('X20', 'X34', 'X37')] = 1.0301125817569319e-07
# 	Remembering Comb[('X20', 'X34', 'X38')] = 1.0724205199217792e-07
# 	Remembering Comb[('X20', 'X34', 'X5')] = 1.0692927258206593e-07
# 	Remembering Comb[('X20', 'X37', 'X38')] = 1.0315227399782152e-07
# 	Remembering Comb[('X20', 'X37', 'X5')] = 1.0488890019824986e-07
# 	Remembering Comb[('X20', 'X38', 'X5')] = 1.0373239531175606e-07
# 	Remembering Comb[('X30', 'X31', 'X32')] = 1.0042079071561397e-07
# 	Remembering Comb[('X30', 'X31', 'X34')] = 1.0131229063451191e-07
# 	Remembering Comb[('X30', 'X31', 'X37')] = 9.937199101287808e-08
# 	Remembering Comb[('X30', 'X31', 'X38')] = 1.0402730197953475e-07
# 	Remembering Comb[('X30', 'X31', 'X5')] = 1.0403563184564763e-07
# 	Remembering Comb[('X30', 'X32', 'X34')] = 1.0174478147742965e-07
# 	Remembering Comb[('X30', 'X32', 'X37')] = 1.0191435935011076e-07
# 	Remembering Comb[('X30', 'X32', 'X38')] = 1.0715701583671757e-07
# 	Remembering Comb[('X30', 'X32', 'X5')] = 1.0450450744093197e-07
# 	Remembering Comb[('X30', 'X34', 'X37')] = 1.010994802496842e-07
# 	Recognized Comb[('X30', 'X34', 'X38')] = 1.0832374098944765e-07
# 	Remembering Comb[('X30', 'X34', 'X5')] = 1.0606965479481293e-07
# 	Remembering Comb[('X30', 'X37', 'X38')] = 1.0160871370107579e-07
# 	Remembering Comb[('X30', 'X37', 'X5')] = 1.0034937674819869e-07
# 	Remembering Comb[('X30', 'X38', 'X5')] = 1.031647173282621e-07
# 	Remembering Comb[('X31', 'X32', 'X34')] = 1.0247287300146509e-07
# 	Remembering Comb[('X31', 'X32', 'X37')] = 1.0077709860391105e-07
# 	Remembering Comb[('X31', 'X32', 'X38')] = 1.075969272709523e-07
# 	Remembering Comb[('X31', 'X32', 'X5')] = 1.0517016366870586e-07
# 	Recognized Comb[('X31', 'X34', 'X37')] = 1.013178435287446e-07
# 	Remembering Comb[('X31', 'X34', 'X38')] = 1.0474815593041386e-07
# 	Remembering Comb[('X31', 'X34', 'X5')] = 1.0684952934418716e-07
# 	Remembering Comb[('X31', 'X37', 'X38')] = 1.0353135706203337e-07
# 	Remembering Comb[('X31', 'X37', 'X5')] = 1.0493081840152458e-07
# 	Remembering Comb[('X31', 'X38', 'X5')] = 1.0871260370399275e-07
# 	Remembering Comb[('X32', 'X34', 'X37')] = 9.941047465002578e-08
# 	Remembering Comb[('X32', 'X34', 'X38')] = 1.0543882645834111e-07
# 	Remembering Comb[('X32', 'X34', 'X5')] = 1.0684046909556476e-07
# 	Remembering Comb[('X32', 'X37', 'X38')] = 1.0443548207897837e-07
# 	Remembering Comb[('X32', 'X37', 'X5')] = 1.038114898626572e-07
# 	Remembering Comb[('X32', 'X38', 'X5')] = 1.09421436538214e-07
# 	Remembering Comb[('X34', 'X37', 'X38')] = 1.0213722774418172e-07
# 	Remembering Comb[('X34', 'X37', 'X5')] = 1.0323009315963721e-07
# 	Remembering Comb[('X34', 'X38', 'X5')] = 1.068857003351511e-07
# 	Remembering Comb[('X37', 'X38', 'X5')] = 1.0586307510595535e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31')] = 1.034399819997068e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32')] = 1.0148532376205889e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X34')] = 1.038688619552538e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X37')] = 1.0395115630544813e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X38')] = 1.0347816741584961e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X5')] = 1.0335203793705208e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32')] = 1.0145545174855973e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X34')] = 1.0480083997081698e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X37')] = 1.0282345646852912e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X38')] = 1.038125730281111e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X5')] = 1.0323494950058736e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X34')] = 1.0227933070989537e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X37')] = 1.0245768761666021e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X38')] = 1.0304277357245634e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X5')] = 1.0092585746459372e-07
# 	Remembering Comb[('X15', 'X20', 'X34', 'X37')] = 1.03655784691914e-07
# 	Remembering Comb[('X15', 'X20', 'X34', 'X38')] = 1.0408005118023545e-07
# 	Remembering Comb[('X15', 'X20', 'X34', 'X5')] = 1.0418825710267569e-07
# 	Remembering Comb[('X15', 'X20', 'X37', 'X38')] = 1.0207698240907713e-07
# 	Remembering Comb[('X15', 'X20', 'X37', 'X5')] = 1.0264325930706478e-07
# 	Remembering Comb[('X15', 'X20', 'X38', 'X5')] = 1.0299507526906339e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32')] = 1.0133191459981682e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X34')] = 1.0425970255328835e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X37')] = 1.0290925696022494e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X38')] = 1.0503357095089232e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X5')] = 1.0586070263288293e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X34')] = 1.0179430424006544e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X37')] = 1.0331096834411338e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X38')] = 1.0328536973049969e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X5')] = 1.0275994779432818e-07
# 	Remembering Comb[('X15', 'X30', 'X34', 'X37')] = 1.0334185778234689e-07
# 	Remembering Comb[('X15', 'X30', 'X34', 'X38')] = 1.0463340564268976e-07
# 	Remembering Comb[('X15', 'X30', 'X34', 'X5')] = 1.0353626762873448e-07
# 	Remembering Comb[('X15', 'X30', 'X37', 'X38')] = 1.0382387468165332e-07
# 	Remembering Comb[('X15', 'X30', 'X37', 'X5')] = 1.0306452208891432e-07
# 	Remembering Comb[('X15', 'X30', 'X38', 'X5')] = 1.0339966354314635e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X34')] = 1.0286484879920301e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X37')] = 1.0198114991969533e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X38')] = 1.0396808395077679e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X5')] = 1.0274448414491398e-07
# 	Remembering Comb[('X15', 'X31', 'X34', 'X37')] = 1.0270909934097781e-07
# 	Remembering Comb[('X15', 'X31', 'X34', 'X38')] = 1.0501700707496267e-07
# 	Remembering Comb[('X15', 'X31', 'X34', 'X5')] = 1.0600921215533303e-07
# 	Remembering Comb[('X15', 'X31', 'X37', 'X38')] = 1.0371260645424249e-07
# 	Remembering Comb[('X15', 'X31', 'X37', 'X5')] = 1.0432381899598413e-07
# 	Remembering Comb[('X15', 'X31', 'X38', 'X5')] = 1.0493125275635093e-07
# 	Remembering Comb[('X15', 'X32', 'X34', 'X37')] = 1.0147198566356062e-07
# 	Remembering Comb[('X15', 'X32', 'X34', 'X38')] = 1.0375411582364151e-07
# 	Remembering Comb[('X15', 'X32', 'X34', 'X5')] = 1.0212629846728513e-07
# 	Remembering Comb[('X15', 'X32', 'X37', 'X38')] = 1.0578596517037062e-07
# 	Remembering Comb[('X15', 'X32', 'X37', 'X5')] = 1.0251995148158192e-07
# 	Remembering Comb[('X15', 'X32', 'X38', 'X5')] = 1.0485678292412294e-07
# 	Remembering Comb[('X15', 'X34', 'X37', 'X38')] = 1.0390313465383321e-07
# 	Remembering Comb[('X15', 'X34', 'X37', 'X5')] = 1.0252366792511281e-07
# 	Remembering Comb[('X15', 'X34', 'X38', 'X5')] = 1.0265676252223609e-07
# 	Remembering Comb[('X15', 'X37', 'X38', 'X5')] = 1.033479665748244e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32')] = 1.0319457878031434e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X34')] = 1.0419640654495149e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X37')] = 1.0230477925022345e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X38')] = 1.0430071858287721e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X5')] = 1.0437576150805347e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X34')] = 1.0401052249583094e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X37')] = 1.037426382633362e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X38')] = 1.0500768134725122e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X5')] = 1.0419877626435824e-07
# 	Remembering Comb[('X20', 'X30', 'X34', 'X37')] = 1.0311056076493977e-07
# 	Remembering Comb[('X20', 'X30', 'X34', 'X38')] = 1.0657559784117211e-07
# 	Remembering Comb[('X20', 'X30', 'X34', 'X5')] = 1.0533462309073032e-07
# 	Remembering Comb[('X20', 'X30', 'X37', 'X38')] = 1.0382855685876205e-07
# 	Remembering Comb[('X20', 'X30', 'X37', 'X5')] = 1.0232012848352505e-07
# 	Remembering Comb[('X20', 'X30', 'X38', 'X5')] = 1.0422237781914387e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X34')] = 1.041208327029478e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X37')] = 1.0114995538279782e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X38')] = 1.0488185782574961e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X5')] = 1.0400738863258196e-07
# 	Recognized Comb[('X20', 'X31', 'X34', 'X37')] = 1.0354823909909216e-07
# 	Remembering Comb[('X20', 'X31', 'X34', 'X38')] = 1.062668458268654e-07
# 	Remembering Comb[('X20', 'X31', 'X34', 'X5')] = 1.0730280448023292e-07
# 	Remembering Comb[('X20', 'X31', 'X37', 'X38')] = 1.0247773231373573e-07
# 	Remembering Comb[('X20', 'X31', 'X37', 'X5')] = 1.037625064592167e-07
# 	Remembering Comb[('X20', 'X31', 'X38', 'X5')] = 1.0600633628640077e-07
# 	Remembering Comb[('X20', 'X32', 'X34', 'X37')] = 1.0051093831125116e-07
# 	Remembering Comb[('X20', 'X32', 'X34', 'X38')] = 1.0563170383746003e-07
# 	Remembering Comb[('X20', 'X32', 'X34', 'X5')] = 1.0387366672572847e-07
# 	Remembering Comb[('X20', 'X32', 'X37', 'X38')] = 1.0426931077706215e-07
# 	Remembering Comb[('X20', 'X32', 'X37', 'X5')] = 1.0366254520146565e-07
# 	Remembering Comb[('X20', 'X32', 'X38', 'X5')] = 1.0573765441359762e-07
# 	Remembering Comb[('X20', 'X34', 'X37', 'X38')] = 1.0428073204693617e-07
# 	Remembering Comb[('X20', 'X34', 'X37', 'X5')] = 1.039721323880221e-07
# 	Remembering Comb[('X20', 'X34', 'X38', 'X5')] = 1.0505104094140697e-07
# 	Remembering Comb[('X20', 'X37', 'X38', 'X5')] = 1.0354400325752304e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X34')] = 1.0115651557528013e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X37')] = 1.0240357672180408e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X38')] = 1.0366019034412932e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X5')] = 1.0473454487235455e-07
# 	Remembering Comb[('X30', 'X31', 'X34', 'X37')] = 1.0223609896770379e-07
# 	Remembering Comb[('X30', 'X31', 'X34', 'X38')] = 1.0629149326293722e-07
# 	Remembering Comb[('X30', 'X31', 'X34', 'X5')] = 1.0605969801892026e-07
# 	Remembering Comb[('X30', 'X31', 'X37', 'X38')] = 1.0401891376602865e-07
# 	Remembering Comb[('X30', 'X31', 'X37', 'X5')] = 1.0392977202727245e-07
# 	Remembering Comb[('X30', 'X31', 'X38', 'X5')] = 1.0458228064095088e-07
# 	Remembering Comb[('X30', 'X32', 'X34', 'X37')] = 1.0222319750932315e-07
# 	Remembering Comb[('X30', 'X32', 'X34', 'X38')] = 1.0605747542871903e-07
# 	Remembering Comb[('X30', 'X32', 'X34', 'X5')] = 1.0393085850718396e-07
# 	Remembering Comb[('X30', 'X32', 'X37', 'X38')] = 1.0476432035733724e-07
# 	Remembering Comb[('X30', 'X32', 'X37', 'X5')] = 1.0274622100522834e-07
# 	Remembering Comb[('X30', 'X32', 'X38', 'X5')] = 1.0493073859105508e-07
# 	Remembering Comb[('X30', 'X34', 'X37', 'X38')] = 1.0417041725673455e-07
# 	Remembering Comb[('X30', 'X34', 'X37', 'X5')] = 1.0290134740440138e-07
# 	Remembering Comb[('X30', 'X34', 'X38', 'X5')] = 1.070984895716003e-07
# 	Remembering Comb[('X30', 'X37', 'X38', 'X5')] = 1.034622813201918e-07
# 	Remembering Comb[('X31', 'X32', 'X34', 'X37')] = 1.0168354177780852e-07
# 	Remembering Comb[('X31', 'X32', 'X34', 'X38')] = 1.0452861018699906e-07
# 	Remembering Comb[('X31', 'X32', 'X34', 'X5')] = 1.0565025011333246e-07
# 	Remembering Comb[('X31', 'X32', 'X37', 'X38')] = 1.0357651285539073e-07
# 	Remembering Comb[('X31', 'X32', 'X37', 'X5')] = 1.0516446468199884e-07
# 	Remembering Comb[('X31', 'X32', 'X38', 'X5')] = 1.0672031246972114e-07
# 	Remembering Comb[('X31', 'X34', 'X37', 'X38')] = 1.0360226005671848e-07
# 	Remembering Comb[('X31', 'X34', 'X37', 'X5')] = 1.0511628188830142e-07
# 	Remembering Comb[('X31', 'X34', 'X38', 'X5')] = 1.0657387949150454e-07
# 	Remembering Comb[('X31', 'X37', 'X38', 'X5')] = 1.0618648898212618e-07
# 	Remembering Comb[('X32', 'X34', 'X37', 'X38')] = 1.0187225181943602e-07
# 	Remembering Comb[('X32', 'X34', 'X37', 'X5')] = 1.0271091362857901e-07
# 	Remembering Comb[('X32', 'X34', 'X38', 'X5')] = 1.0552548190321402e-07
# 	Remembering Comb[('X32', 'X37', 'X38', 'X5')] = 1.0544205247068328e-07
# 	Remembering Comb[('X34', 'X37', 'X38', 'X5')] = 1.0329752728627217e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32')] = 1.054980792207751e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X34')] = 1.0502288019906042e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X37')] = 1.0493382074906139e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X38')] = 1.0571796877506335e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X5')] = 1.0483979218604014e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X34')] = 1.0518288589676637e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X37')] = 1.0796641579739169e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X38')] = 1.062439979684983e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X5')] = 1.0488594773972389e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X34', 'X37')] = 1.0488997999344255e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X34', 'X38')] = 1.0513364027209463e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X34', 'X5')] = 1.0513844131236083e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X37', 'X38')] = 1.0538882443142551e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X37', 'X5')] = 1.0491463882286e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X38', 'X5')] = 1.0445600538618568e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X34')] = 1.0490249387165974e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X37')] = 1.0509206241550439e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X38')] = 1.052621358362976e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X5')] = 1.0432934224454186e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X34', 'X37')] = 1.0490079483016524e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X34', 'X38')] = 1.0673880869222565e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X34', 'X5')] = 1.0525966499153472e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X37', 'X38')] = 1.048407392246189e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X37', 'X5')] = 1.0454583836406741e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X38', 'X5')] = 1.0510284381255549e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X34', 'X37')] = 1.0434124336242061e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X34', 'X38')] = 1.0572114383905821e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X34', 'X5')] = 1.0410323676548666e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X37', 'X38')] = 1.0655650960988479e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X37', 'X5')] = 1.0479916491298375e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X38', 'X5')] = 1.0493365138328974e-07
# 	Remembering Comb[('X15', 'X20', 'X34', 'X37', 'X38')] = 1.049427842109987e-07
# 	Remembering Comb[('X15', 'X20', 'X34', 'X37', 'X5')] = 1.0430169419930404e-07
# 	Remembering Comb[('X15', 'X20', 'X34', 'X38', 'X5')] = 1.0451254311505897e-07
# 	Remembering Comb[('X15', 'X20', 'X37', 'X38', 'X5')] = 1.0422392758283982e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X34')] = 1.0379078383989869e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X37')] = 1.0549789953691874e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X38')] = 1.0454215809715948e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X5')] = 1.05416035453629e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X34', 'X37')] = 1.0370343631986901e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X34', 'X38')] = 1.0540597478306639e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X34', 'X5')] = 1.0551231504737653e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X37', 'X38')] = 1.053170520648041e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X37', 'X5')] = 1.0526098294797539e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X38', 'X5')] = 1.0511673261058598e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X34', 'X37')] = 1.0548627326745693e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X34', 'X38')] = 1.0488771542265294e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X34', 'X5')] = 1.0392165866081343e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X37', 'X38')] = 1.067857088002603e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X37', 'X5')] = 1.0566486754020301e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X38', 'X5')] = 1.0516195927472869e-07
# 	Remembering Comb[('X15', 'X30', 'X34', 'X37', 'X38')] = 1.0441891915334753e-07
# 	Remembering Comb[('X15', 'X30', 'X34', 'X37', 'X5')] = 1.0469587862387385e-07
# 	Remembering Comb[('X15', 'X30', 'X34', 'X38', 'X5')] = 1.0470663064511552e-07
# 	Remembering Comb[('X15', 'X30', 'X37', 'X38', 'X5')] = 1.0475811964651157e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X34', 'X37')] = 1.0367900255232753e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X34', 'X38')] = 1.0520912386760818e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X34', 'X5')] = 1.0476462708980268e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X37', 'X38')] = 1.0574588906211223e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X37', 'X5')] = 1.0425882915273306e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X38', 'X5')] = 1.0493152506178837e-07
# 	Remembering Comb[('X15', 'X31', 'X34', 'X37', 'X38')] = 1.0452802903122895e-07
# 	Remembering Comb[('X15', 'X31', 'X34', 'X37', 'X5')] = 1.0546980089168853e-07
# 	Remembering Comb[('X15', 'X31', 'X34', 'X38', 'X5')] = 1.0460372768122444e-07
# 	Remembering Comb[('X15', 'X31', 'X37', 'X38', 'X5')] = 1.050835726779955e-07
# 	Remembering Comb[('X15', 'X32', 'X34', 'X37', 'X38')] = 1.0441490391646289e-07
# 	Remembering Comb[('X15', 'X32', 'X34', 'X37', 'X5')] = 1.0311978955394367e-07
# 	Remembering Comb[('X15', 'X32', 'X34', 'X38', 'X5')] = 1.0427732491009937e-07
# 	Remembering Comb[('X15', 'X32', 'X37', 'X38', 'X5')] = 1.0567125433306671e-07
# 	Remembering Comb[('X15', 'X34', 'X37', 'X38', 'X5')] = 1.0293622720630368e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X34')] = 1.046580239294281e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X37')] = 1.0500000642561198e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X38')] = 1.0531693357068986e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X5')] = 1.0537564004150434e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X34', 'X37')] = 1.0460068453073387e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X34', 'X38')] = 1.0637865003814849e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X34', 'X5')] = 1.0601609065791794e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X37', 'X38')] = 1.0481803826078012e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X37', 'X5')] = 1.0393104424569998e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X38', 'X5')] = 1.0588300948442623e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X34', 'X37')] = 1.046419605028028e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X34', 'X38')] = 1.0624796494877288e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X34', 'X5')] = 1.0503400839248071e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X37', 'X38')] = 1.0646016207563408e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X37', 'X5')] = 1.0586813226585992e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X38', 'X5')] = 1.0557952994751703e-07
# 	Remembering Comb[('X20', 'X30', 'X34', 'X37', 'X38')] = 1.0494877547514443e-07
# 	Remembering Comb[('X20', 'X30', 'X34', 'X37', 'X5')] = 1.0389763770913888e-07
# 	Remembering Comb[('X20', 'X30', 'X34', 'X38', 'X5')] = 1.0540557197290161e-07
# 	Remembering Comb[('X20', 'X30', 'X37', 'X38', 'X5')] = 1.0426287606263323e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X34', 'X37')] = 1.0320878703797068e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X34', 'X38')] = 1.0631755078626914e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X34', 'X5')] = 1.05821386005936e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X37', 'X38')] = 1.04772849210598e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X37', 'X5')] = 1.0488532826634807e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X38', 'X5')] = 1.0567130966436667e-07
# 	Remembering Comb[('X20', 'X31', 'X34', 'X37', 'X38')] = 1.0456508876892539e-07
# 	Remembering Comb[('X20', 'X31', 'X34', 'X37', 'X5')] = 1.0548261531217721e-07
# 	Remembering Comb[('X20', 'X31', 'X34', 'X38', 'X5')] = 1.0589140467095493e-07
# 	Remembering Comb[('X20', 'X31', 'X37', 'X38', 'X5')] = 1.0437298214984015e-07
# 	Remembering Comb[('X20', 'X32', 'X34', 'X37', 'X38')] = 1.0461843748880084e-07
# 	Remembering Comb[('X20', 'X32', 'X34', 'X37', 'X5')] = 1.0400985219598722e-07
# 	Remembering Comb[('X20', 'X32', 'X34', 'X38', 'X5')] = 1.051553614135426e-07
# 	Remembering Comb[('X20', 'X32', 'X37', 'X38', 'X5')] = 1.0567561929127842e-07
# 	Remembering Comb[('X20', 'X34', 'X37', 'X38', 'X5')] = 1.0451704863596014e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X34', 'X37')] = 1.0430292985925148e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X34', 'X38')] = 1.0567740710250966e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X34', 'X5')] = 1.0451138224374082e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X37', 'X38')] = 1.0611936185257459e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X37', 'X5')] = 1.055946001890009e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X38', 'X5')] = 1.055118445845992e-07
# 	Remembering Comb[('X30', 'X31', 'X34', 'X37', 'X38')] = 1.0459185950350083e-07
# 	Remembering Comb[('X30', 'X31', 'X34', 'X37', 'X5')] = 1.0534743901300066e-07
# 	Remembering Comb[('X30', 'X31', 'X34', 'X38', 'X5')] = 1.0603008560571074e-07
# 	Remembering Comb[('X30', 'X31', 'X37', 'X38', 'X5')] = 1.0575117571230933e-07
# 	Remembering Comb[('X30', 'X32', 'X34', 'X37', 'X38')] = 1.0545835465667966e-07
# 	Remembering Comb[('X30', 'X32', 'X34', 'X37', 'X5')] = 1.0464980143910074e-07
# 	Remembering Comb[('X30', 'X32', 'X34', 'X38', 'X5')] = 1.0605253649672261e-07
# 	Remembering Comb[('X30', 'X32', 'X37', 'X38', 'X5')] = 1.0548805440260123e-07
# 	Remembering Comb[('X30', 'X34', 'X37', 'X38', 'X5')] = 1.0436858793058499e-07
# 	Remembering Comb[('X31', 'X32', 'X34', 'X37', 'X38')] = 1.0328297682508275e-07
# 	Remembering Comb[('X31', 'X32', 'X34', 'X37', 'X5')] = 1.0546516614628781e-07
# 	Remembering Comb[('X31', 'X32', 'X34', 'X38', 'X5')] = 1.0532358922000716e-07
# 	Remembering Comb[('X31', 'X32', 'X37', 'X38', 'X5')] = 1.0660562905773903e-07
# 	Remembering Comb[('X31', 'X34', 'X37', 'X38', 'X5')] = 1.0453995881229195e-07
# 	Remembering Comb[('X32', 'X34', 'X37', 'X38', 'X5')] = 1.0322122816331089e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X34')] = 1.259362669442052e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X37')] = 1.4584342236894176e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X38')] = 1.313752249336784e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X5')] = 1.3080156043297415e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X34', 'X37')] = 1.2386507882680532e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X34', 'X38')] = 1.1701431424969869e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X34', 'X5')] = 1.171328625098356e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X37', 'X38')] = 1.2984016829694784e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X37', 'X5')] = 1.2867200797120022e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X38', 'X5')] = 1.1899321965721677e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X34', 'X37')] = 1.4277280766665042e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X34', 'X38')] = 1.3042448564716728e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X34', 'X5')] = 1.2735625870607023e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X37', 'X38')] = 1.4414077753311717e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X37', 'X5')] = 1.4829771251950064e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X38', 'X5')] = 1.3209185235423212e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X34', 'X37', 'X38')] = 1.2643201200288274e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X34', 'X37', 'X5')] = 1.2523159903358736e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X34', 'X38', 'X5')] = 1.1741026556910602e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X37', 'X38', 'X5')] = 1.2844471887358348e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X34', 'X37')] = 1.2821843757170657e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X34', 'X38')] = 1.1999394770618188e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X34', 'X5')] = 1.1912338710427878e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X37', 'X38')] = 1.3203417976137017e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X37', 'X5')] = 1.299226824459027e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X38', 'X5')] = 1.1920332017508754e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X34', 'X37', 'X38')] = 1.1721026568963988e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X34', 'X37', 'X5')] = 1.1766194567726896e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X34', 'X38', 'X5')] = 1.1295155673214974e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X37', 'X38', 'X5')] = 1.189893309765365e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X34', 'X37', 'X38')] = 1.2757879031438926e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X34', 'X37', 'X5')] = 1.288782229288842e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X34', 'X38', 'X5')] = 1.1994275838299807e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X37', 'X38', 'X5')] = 1.3316686981852557e-07
# 	Remembering Comb[('X15', 'X20', 'X34', 'X37', 'X38', 'X5')] = 1.1748946304795818e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X34', 'X37')] = 1.2795664377609064e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X34', 'X38')] = 1.1831782764490689e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X34', 'X5')] = 1.1999408137052536e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X37', 'X38')] = 1.3360487422328347e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X37', 'X5')] = 1.3171279660674326e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X38', 'X5')] = 1.2156675164348952e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X34', 'X37', 'X38')] = 1.1674866617433732e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X34', 'X37', 'X5')] = 1.1732325390162708e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X34', 'X38', 'X5')] = 1.1025076653849341e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X37', 'X38', 'X5')] = 1.198664765360293e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X34', 'X37', 'X38')] = 1.3004858550536194e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X34', 'X37', 'X5')] = 1.2905973943800666e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X34', 'X38', 'X5')] = 1.2003957984936776e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X37', 'X38', 'X5')] = 1.3269121073704704e-07
# 	Remembering Comb[('X15', 'X30', 'X34', 'X37', 'X38', 'X5')] = 1.1743773280841154e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X34', 'X37', 'X38')] = 1.1834459033598327e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X34', 'X37', 'X5')] = 1.1849916842429258e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X34', 'X38', 'X5')] = 1.1251455416280493e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X37', 'X38', 'X5')] = 1.208234778863484e-07
# 	Remembering Comb[('X15', 'X31', 'X34', 'X37', 'X38', 'X5')] = 1.1150315511557089e-07
# 	Remembering Comb[('X15', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.1938154549408577e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X34', 'X37')] = 1.2882049613482198e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X34', 'X38')] = 1.2055357502940332e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X34', 'X5')] = 1.1993905237738423e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X37', 'X38')] = 1.3144983648976876e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X37', 'X5')] = 1.292236148721913e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X38', 'X5')] = 1.2254830354349385e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X34', 'X37', 'X38')] = 1.1816881917465611e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X34', 'X37', 'X5')] = 1.1681858640895286e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X34', 'X38', 'X5')] = 1.1248732673331493e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X37', 'X38', 'X5')] = 1.1856962742085207e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X34', 'X37', 'X38')] = 1.287801593538061e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X34', 'X37', 'X5')] = 1.2919876218560258e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X34', 'X38', 'X5')] = 1.1920158199307461e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X37', 'X38', 'X5')] = 1.313161804871578e-07
# 	Remembering Comb[('X20', 'X30', 'X34', 'X37', 'X38', 'X5')] = 1.1641647172696718e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X34', 'X37', 'X38')] = 1.1841363770288795e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X34', 'X37', 'X5')] = 1.2001015154286156e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X34', 'X38', 'X5')] = 1.1441576006993289e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X37', 'X38', 'X5')] = 1.2271492789102373e-07
# 	Remembering Comb[('X20', 'X31', 'X34', 'X37', 'X38', 'X5')] = 1.1212969853089238e-07
# 	Remembering Comb[('X20', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.1857573965699611e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X34', 'X37', 'X38')] = 1.2161010001340878e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X34', 'X37', 'X5')] = 1.1971695204031945e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X34', 'X38', 'X5')] = 1.1416041351649242e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X37', 'X38', 'X5')] = 1.2385632054562042e-07
# 	Remembering Comb[('X30', 'X31', 'X34', 'X37', 'X38', 'X5')] = 1.1160177741331486e-07
# 	Remembering Comb[('X30', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.1970545305513846e-07
# 	Remembering Comb[('X31', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.1130002807239419e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X34', 'X37')] = 2.1661855235123987e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X34', 'X38')] = 2.0079235903418855e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X34', 'X5')] = 2.0303526692497083e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X37', 'X38')] = 2.175801799338209e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X37', 'X5')] = 2.1989372987100344e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X38', 'X5')] = 1.9793332182134358e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X34', 'X37', 'X38')] = 2.085072412554848e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X34', 'X37', 'X5')] = 2.0533129197667467e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X34', 'X38', 'X5')] = 1.8527740235916182e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X37', 'X38', 'X5')] = 2.039600962440689e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X34', 'X37', 'X38')] = 2.145555093106364e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X34', 'X37', 'X5')] = 2.143294854614674e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X34', 'X38', 'X5')] = 2.0014610495639266e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X37', 'X38', 'X5')] = 2.139445659007168e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X34', 'X37', 'X38', 'X5')] = 2.0247149657025248e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X34', 'X37', 'X38')] = 2.0403493084098365e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X34', 'X37', 'X5')] = 2.0374440167603973e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X34', 'X38', 'X5')] = 1.8279961142437948e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X37', 'X38', 'X5')] = 2.017028724539546e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X34', 'X37', 'X38', 'X5')] = 1.8194079201517215e-07
# 	Remembering Comb[('X15', 'X20', 'X32', 'X34', 'X37', 'X38', 'X5')] = 2.0053513223761685e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X34', 'X37', 'X38')] = 2.0285736785294781e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X34', 'X37', 'X5')] = 2.0315944873622217e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X34', 'X38', 'X5')] = 1.7528745174736776e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X37', 'X38', 'X5')] = 2.0227662507096007e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X34', 'X37', 'X38', 'X5')] = 1.837464954205516e-07
# 	Remembering Comb[('X15', 'X30', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.9700835935062266e-07
# 	Remembering Comb[('X15', 'X31', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.8283016435138885e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X34', 'X37', 'X38')] = 2.0167205969137228e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X34', 'X37', 'X5')] = 2.0313474676418103e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X34', 'X38', 'X5')] = 1.8077359738216927e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X37', 'X38', 'X5')] = 2.0008271702697078e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X34', 'X37', 'X38', 'X5')] = 1.8171505481308884e-07
# 	Remembering Comb[('X20', 'X30', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.967874265759594e-07
# 	Remembering Comb[('X20', 'X31', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.7884804683695436e-07
# 	Remembering Comb[('X30', 'X31', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.8228487064375785e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X34', 'X37', 'X38')] = 1.9210306268963617e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X34', 'X37', 'X5')] = 1.9502952955483012e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X34', 'X38', 'X5')] = 2.1191407396828661e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X37', 'X38', 'X5')] = 1.9567923876617855e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X34', 'X37', 'X38', 'X5')] = 2.1373120232231556e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.9962905982785223e-07
# 	Remembering Comb[('X15', 'X20', 'X31', 'X32', 'X34', 'X37', 'X38', 'X5')] = 2.1293702830073756e-07
# 	Remembering Comb[('X15', 'X30', 'X31', 'X32', 'X34', 'X37', 'X38', 'X5')] = 2.1575972016546604e-07
# 	Remembering Comb[('X20', 'X30', 'X31', 'X32', 'X34', 'X37', 'X38', 'X5')] = 2.1616875646063192e-07
# 	Remembering Comb[('X15', 'X20', 'X30', 'X31', 'X32', 'X34', 'X37', 'X38', 'X5')] = 1.0696377268697013e-07
# ('X15', 'X18', 'X20', 'X31', 'X38')
# 	Recognized Comb[('X15',)] = 8.720948197569742e-08
# 	Recognized Comb[('X18',)] = 1.091839148799073e-07
# 	Recognized Comb[('X20',)] = 1.0620547744865459e-07
# 	Recognized Comb[('X31',)] = 9.784821407576818e-08
# 	Recognized Comb[('X38',)] = 9.990015214166418e-08
# 	Remembering Comb[('X15', 'X18')] = 9.69616767347323e-08
# 	Recognized Comb[('X15', 'X20')] = 9.401178780031829e-08
# 	Recognized Comb[('X15', 'X31')] = 1.00167312338887e-07
# 	Recognized Comb[('X15', 'X38')] = 9.685041565605953e-08
# 	Recognized Comb[('X18', 'X20')] = 1.0367023347042551e-07
# 	Recognized Comb[('X18', 'X31')] = 1.097388836979963e-07
# 	Recognized Comb[('X18', 'X38')] = 1.0973159114650887e-07
# 	Recognized Comb[('X20', 'X31')] = 1.0121914132146794e-07
# 	Recognized Comb[('X20', 'X38')] = 1.0223122850738607e-07
# 	Recognized Comb[('X31', 'X38')] = 1.0407126965585849e-07
# 	Remembering Comb[('X15', 'X18', 'X20')] = 9.791630088135479e-08
# 	Remembering Comb[('X15', 'X18', 'X31')] = 1.0362891496791351e-07
# 	Remembering Comb[('X15', 'X18', 'X38')] = 1.0109096210803786e-07
# 	Recognized Comb[('X15', 'X20', 'X31')] = 1.0020092288616913e-07
# 	Recognized Comb[('X15', 'X20', 'X38')] = 9.82277035320667e-08
# 	Recognized Comb[('X15', 'X31', 'X38')] = 1.0325546433737277e-07
# 	Recognized Comb[('X18', 'X20', 'X31')] = 1.0868428243220747e-07
# 	Recognized Comb[('X18', 'X20', 'X38')] = 1.0531615077338009e-07
# 	Recognized Comb[('X18', 'X31', 'X38')] = 1.1043400197851377e-07
# 	Recognized Comb[('X20', 'X31', 'X38')] = 1.0387377328182131e-07
# 	Remembering Comb[('X15', 'X18', 'X20', 'X31')] = 1.0461388428214873e-07
# 	Remembering Comb[('X15', 'X18', 'X20', 'X38')] = 1.0244882509925463e-07
# 	Remembering Comb[('X15', 'X18', 'X31', 'X38')] = 1.064213717494518e-07
# 	Recognized Comb[('X15', 'X20', 'X31', 'X38')] = 1.038125730281111e-07
# 	Recognized Comb[('X18', 'X20', 'X31', 'X38')] = 1.0761072519325023e-07
# 	Remembering Comb[('X15', 'X18', 'X20', 'X31', 'X38')] = 1.0812808840912327e-07
# ('X16', 'X30', 'X31', 'X32')
# 	Recognized Comb[('X16',)] = 9.77956276711301e-08
# 	Recognized Comb[('X30',)] = 9.623927447860778e-08
# 	Recognized Comb[('X31',)] = 9.784821407576818e-08
# 	Recognized Comb[('X32',)] = 1.0952058602166966e-07
# 	Remembering Comb[('X16', 'X30')] = 9.976975177644322e-08
# 	Recognized Comb[('X16', 'X31')] = 1.0768220350862676e-07
# 	Remembering Comb[('X16', 'X32')] = 1.0981027162520994e-07
# 	Recognized Comb[('X30', 'X31')] = 9.76054833401526e-08
# 	Recognized Comb[('X30', 'X32')] = 1.0342415570079469e-07
# 	Recognized Comb[('X31', 'X32')] = 1.0498811156491484e-07
# 	Remembering Comb[('X16', 'X30', 'X31')] = 1.0558355494666974e-07
# 	Remembering Comb[('X16', 'X30', 'X32')] = 1.0274913252594723e-07
# 	Remembering Comb[('X16', 'X31', 'X32')] = 1.0927122940628456e-07
# 	Recognized Comb[('X30', 'X31', 'X32')] = 1.0042079071561397e-07
# 	Remembering Comb[('X16', 'X30', 'X31', 'X32')] = 1.056000466842137e-07

# %%
from itertools import combinations
import concurrent.futures
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor

def compute_variance_viaindexesv2(indexes: list, variable: str, parents: list):
    conditional_probs_record = merged_df[parents + [variable]].groupby(parents + [variable]).count().reset_index()
    mll_list = []
    env = 0
    for index in indexes:
        vertical_sampled_data = merged_df.iloc[index].reset_index()
        vertical_sampled_data = vertical_sampled_data.drop(columns=['index'])
        vertical_sampled_data.insert(0, 'count', [1] * len(vertical_sampled_data))
        
        summary_with_ch = vertical_sampled_data.groupby(parents + [variable])['count'].sum().reset_index()
        mll, output = compute_mll(summary_with_ch, parents, env)
        conditional_probs_record = conditional_probs_record.merge(output, on=parents + [variable], how='left')
        mll_list.append(mll)
        env += 1
    
    mean_mll = np.mean(mll_list)
    var_avg = conditional_probs_record.iloc[:, len(parents) + 1:].var(axis=1, skipna=True).mean()
    return var_avg, mean_mll, conditional_probs_record


def compute_weighted_variance_viaindexesv2(indexes: list, variable: str, parents: list):
    variance, _, df = compute_variance_viaindexesv2(indexes, variable, parents)
    if len(parents):
        joint_mat = np.array([df[f'joint_{i}'] for i in range(len(indexes))]).T
        probs_mat = np.array([df[f'probs_{i}'] for i in range(len(indexes))]).T
        probs_mean = []
        for i in range(probs_mat.shape[0]):
            if len(probs_mat[i][~np.isnan(probs_mat[i])]):
                probs_mean.append(np.mean(probs_mat[i][~np.isnan(probs_mat[i])]).item())
            else:
                probs_mean.append(0)
                
        probs_mean = np.expand_dims(np.array(probs_mean), 1)
        prod = joint_mat * (probs_mat - probs_mean)**2
        return np.mean(prod[~np.isnan(prod)]), parents
    else:
        return variance, parents
    

def individual_causal_search(var, all_test_cases, silos_index, invariance_hardcap=1e-3):
    print("Here in", var)
    best_variance = invariance_hardcap
    best_comb = ['initiated']
    buffers = {}

    for test_case in all_test_cases:
        for l in range(1, len(test_case) + 1):
            results = []
            for comb in list(combinations(test_case, l)):
                key = tuple(sorted(comb))
                if key in buffers.keys():
                    variance = buffers[key]
                else:
                    variance, _ = compute_weighted_variance_viaindexesv2(silos_index, var, list(key))
                    buffers[key] = variance
                results.append([variance, key])
                
            lowest_variance, cor_comb = sorted(results, key=lambda item: item[0])[0]
            if lowest_variance < best_variance:
                best_variance = lowest_variance
                best_comb = cor_comb

    print("Done with", var)
    return {var: (best_comb, best_variance)}
  
 
# def F_wrapper(args):
#     return individual_causal_search(*args)

# Function to execute F in parallel with limited concurrency
# results = []
# def run_in_parallel2(func, args_list, max_parallel_executions):
#     with ProcessPoolExecutor(max_workers=max_parallel_executions) as executor:
#         future_to_arg = {executor.submit(func, args): args for args in args_list}
#         for future in concurrent.futures.as_completed(future_to_arg):
#             arg = future_to_arg[future]
#             try:
#                 result = future.result()
#                 results.append(result)
#             except Exception as exc:
#                 print(f'{arg} generated an exception: {exc}')
#     return results

# true_causal_parents = {var: [] for var in all_vars}
# invariance_hardcap = 1e-3
# outputs = []
# inputs = [[var, potential_parents[var], silos_index] for var in true_causal_parents]
# outputs = run_in_parallel2(F_wrapper, inputs, max_parallel_executions=32)

# %%
from multiprocessing import Pool
from typing import List, Tuple

# Function to execute F in parallel
def execute_in_parallel(args_list: List[Tuple]):
    with Pool() as pool:
        # Map the function F to the arguments in parallel
        results = pool.starmap(individual_causal_search, args_list)
    return results

# %%
potential_parents['X1']
# Out:
# [('X12', 'X15', 'X18', 'X38', 'X4', 'X8')]

# %%
potential_parents['X2']
# Out:
# [('X18', 'X20', 'X31', 'X33', 'X38'),
#  ('X29', 'X30', 'X34', 'X38'),
#  ('X20', 'X28', 'X31', 'X34', 'X37'),
#  ('X16', 'X18', 'X31', 'X33'),
#  ('X28', 'X29', 'X3', 'X34'),
#  ('X18', 'X29', 'X33', 'X38'),
#  ('X15', 'X20', 'X30', 'X31', 'X32', 'X34', 'X37', 'X38', 'X5'),
#  ('X15', 'X18', 'X20', 'X31', 'X38'),
#  ('X16', 'X30', 'X31', 'X32')]

# %%
true_causal_parents = {var: [] for var in all_vars}
invariance_hardcap = 1e-3

outputs = []
inputs = [(var, potential_parents[var], silos_index, invariance_hardcap) for var in ['X1', 'X2']] #true_causal_parents
outputs = execute_in_parallel(inputs)
# Out:
# Here in X1
# Here in X2
# Done with X1
# Done with X2

# %%
outputs
# Out:
# [{'X1': (('X15',), 1.505700393542893e-07)},
#  {'X2': (('X15',), 8.720948197569742e-08)}]

# %%
tmp = ()
for item in outputs:
    tmp += tuple(item.items())

tmp = dict(tmp)
tmp
# Out:
# {'X1': (('X15',), 1.505700393542893e-07),
#  'X2': (('X15',), 8.720948197569742e-08)}

# %%
adj_mtx = np.zeros([len(all_vars), len(all_vars)])
for var in tmp.keys():
    if len(tmp[var]):
        parents, invariance = tmp[var]
        var_id = int(var[1:]) - 1
        for pa in parents:
            pa_id = int(pa[1:]) - 1
            if adj_mtx[var_id][pa_id] == 0:
                adj_mtx[pa_id][var_id] = invariance
            elif adj_mtx[var_id][pa_id] > adj_mtx[pa_id][var_id]:
                adj_mtx[pa_id][var_id] = invariance
                adj_mtx[var_id][pa_id] = 0
                
adj_mtx[:,0]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.50570039e-07, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
# old code

from itertools import combinations
import numpy as np


potential_parents = {var: [] for var in all_vars}
children = {var: [] for var in all_vars}
invariance_hardcap = 0.001
max_size = 8

repeat = 1
adj_record = []


for _ in range(repeat):
    for anchor_var in markov_blankets.keys():
        markov_variables = list(set(markov_blankets[anchor_var]) - set(children[anchor_var]))
        if len(markov_variables) < 1:
            continue
        
        lowest_variance = 1e2
        best_comb = []
        
        for l in range(1, len(markov_variables) + 1):
            results = []
            inputs = [[silos_index, anchor_var, list(comb)] for comb in list(combinations(markov_variables, l))]
            results = run_in_parallel2(F_wrapper, inputs, max_parallel_executions=64)
            lowest_variance, best_comb = sorted(results, key=lambda item: item[0])[0]

        potential_parents[anchor_var] = (best_comb, lowest_variance) # type:ignore
        
    adj_mtx = np.zeros([len(all_vars), len(all_vars)])
    for var in potential_parents.keys():
        if len(potential_parents[var]):
            parents, invariance = potential_parents[var]
            var_id = int(var[1:]) - 1
            for pa in parents:
                pa_id = int(pa[1:]) - 1
                if adj_mtx[var_id][pa_id] == 0:
                    adj_mtx[pa_id][var_id] = invariance
                elif adj_mtx[var_id][pa_id] > adj_mtx[pa_id][var_id]:
                    adj_mtx[pa_id][var_id] = invariance
                    adj_mtx[var_id][pa_id] = 0


    for i in range(len(all_vars)):
        children[f'X{i+1}'] = []
        for j in range(len(all_vars)):
            if adj_mtx[i][j] > 0:
                children[f'X{i+1}'].append(f'X{j+1}')
                
    adj_record.append(adj_mtx)
    if len(adj_record) >= 2:
        if np.sum(adj_record[-1] - adj_record[-2]) == 0:
            break

# %%
from plot_utils import true_edge, spur_edge, fals_edge, miss_edge, swap_pos

for fin_adjmtx in adj_record:
    # fin_adjmtx = adj_record[-1]

    etrue = true_edge(groundtruth, fin_adjmtx)
    espur = spur_edge(groundtruth, fin_adjmtx)
    efals = fals_edge(groundtruth, fin_adjmtx)
    emiss = miss_edge(groundtruth, fin_adjmtx)

    # print(etrue)
    print(len(etrue), len(espur), len(emiss), len(efals))
# Out:
# 8 3 0 0
# 8 3 0 0
# 8 3 0 0

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.DiGraph()

fin_adjmtx = adj_record[0]

for i in range(fin_adjmtx.shape[0]):
    for j in range(fin_adjmtx.shape[1]):
        if fin_adjmtx[i][j] > 0:
            G.add_edge(f"X{i+1}", f"X{j+1}", weight=np.round(1/fin_adjmtx[i][j],2))
            # print("Here add edge", f"X{i+1}", f"X{j+1}")
    G.add_node(f"X{i+1}")
    

etrue = true_edge(groundtruth, fin_adjmtx)
espur = spur_edge(groundtruth, fin_adjmtx)
efals = fals_edge(groundtruth, fin_adjmtx)
emiss = miss_edge(groundtruth, fin_adjmtx)

# print(etrue)
print(len(etrue), len(espur), len(emiss), len(efals))

pos = nx.shell_layout(G)
pos = swap_pos(pos, 'X4', 'X3')
# pos = swap_pos(pos, 'X3', 'X5')
# pos = swap_pos(pos, 'X10', 'X5')
# pos = swap_pos(pos, 'X10', 'X8')
# pos = swap_pos(pos, 'X8', 'X3')
# pos = swap_pos(pos, 'X6', 'X5')
# pos = swap_pos(pos, 'X1', 'X2')
# pos = swap_pos(pos, 'X11', 'X8')
# pos = swap_pos(pos, 'X7', 'X19')
# pos = swap_pos(pos, 'X20', 'X7')
# pos = swap_pos(pos, 'X18', 'X16')


# nodes
nx.draw_networkx_nodes(G, pos, node_size=400, node_color="#1f78b4")

# edges
nx.draw_networkx_edges(G, pos, edgelist=espur, width=2, arrowstyle='->', arrowsize=20, edge_color="orange", label="Spurious Edges")
nx.draw_networkx_edges(G, pos, edgelist=emiss, width=2, arrowstyle='->', arrowsize=20, edge_color="purple", label="Missing Edges")
nx.draw_networkx_edges(G, pos, edgelist=efals, width=2, arrowstyle='->', arrowsize=20, edge_color="red", label="Anti-Causal Edges")
nx.draw_networkx_edges(G, pos, edgelist=etrue, width=2, arrowstyle='->', arrowsize=20, edge_color="green", label="Causal Edges")

# node labels
nx.draw_networkx_labels(G, pos, font_size=12, font_family="sans-serif", font_color='white')

# edge weight labels
# edge_labels = nx.get_edge_attributes(G, "weight")
# nx.draw_networkx_edge_labels(G, pos, edge_labels)

ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
plt.tight_layout()
# plt.box()
plt.title(dataname.upper())
# plt.legend()
plt.show()

# plt.savefig("res/asia.plot.svg", format="svg")

# %%
# for anchor_var in mk_with_freq.keys():
anchor_var = 'X6'
print("anchor_var:", anchor_var, end="")
print(mk_with_freq[anchor_var])
markov_variables = mk_with_freq[anchor_var]
if len(markov_variables) < 1:
    pass
else:
    lowest_variance = 1e2
    best_comb = []

    print("anchor var:", anchor_var, "Len(markov) = ", len(markov_variables))
    for l in range(1, len(markov_variables) + 1):
        for comb in list(combinations(markov_variables, l)):
            comb_variance = compute_weighted_variance_viasilos(silos, anchor_var, list(comb)) # type:ignore
            print("\tdoing comb", comb, "variance:", comb_variance)
            if comb_variance < lowest_variance and comb_variance < invariance_hardcap:
                lowest_variance = comb_variance
                best_comb = list(comb)

    print("\tParents:", best_comb, "\tVariance:", lowest_variance)
    potential_parents[anchor_var] = (best_comb, lowest_variance) # type:ignore

# %%
# Parents: ['X4'] 	Variance: 1.1418060575318796e-06
